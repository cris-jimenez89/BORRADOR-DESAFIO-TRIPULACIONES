# %%
# NUEVA PRUEBA CON PYTRENDS, LA PRIMERA VEZ ME FUNCIONO!!!! al darle de segunda no 
from pytrends.request import TrendReq

# Inicializar objeto pytrends
pytrends = TrendReq(hl='en-US', tz=360)

# Buscar topics relacionados con una palabra clave
topics = pytrends.suggestions('Jobs')

# Imprimir los topics encontrados
print("Topics relacionados con 'jobs':")
for topic in topics:
    print(topic)

# Seleccionar el código del topic de interés
topic_code = topics[0]['mid']  # Seleccionamos el primer topic como ejemplo

# Realizar la consulta a Google Trends utilizando el código del topic
pytrends.build_payload(kw_list=[topic_code], timeframe='today 12-m', geo='US')
data = pytrends.interest_over_time()

# Imprimir los datos obtenidos
print("\nDatos de Google Trends para el topic seleccionado:")
print(data)
# esto es solo una prueba, pero no hemos puesto los rangos adecuados, ni de tiempo ni de pais
# Out:
# Topics relacionados con 'jobs':
# {'mid': '/g/11f5_qj1qd', 'title': 'JOBST', 'type': 'Topic'}
# {'mid': '/m/04115t2', 'title': 'Job', 'type': 'Topic'}
# {'mid': '/g/11gzr_bn9y', 'title': 'jobsfree', 'type': 'Topic'}
# {'mid': '/g/11j8qrlbls', 'title': 'Online jobs', 'type': 'Topic'}
# {'mid': '/g/11pztx_8k3', 'title': 'Twisted Lies: The Viral TikTok Sensation!', 'type': 'Book by Ana Huang'}
#
# Datos de Google Trends para el topic seleccionado:
#             /g/11f5_qj1qd  isPartial
# date
# 2023-03-26             99      False
# 2023-04-02             71      False
# 2023-04-09             74      False
# 2023-04-16             83      False
# 2023-04-23             78      False
# 2023-04-30             71      False
# 2023-05-07             75      False
# 2023-05-14             74      False
# 2023-05-21             90      False
# 2023-05-28             83      False
# 2023-06-04             89      False
# 2023-06-11             74      False
# ...

# %%
data
# la columna isPartial determina si los datos son parciales o no
# Out:
#             /g/11f5_qj1qd  isPartial
# date
# 2023-03-26             93      False
# 2023-04-02             72      False
# 2023-04-09             80      False
# 2023-04-16             89      False
# 2023-04-23             70      False
# 2023-04-30             77      False
# 2023-05-07             63      False
# 2023-05-14             62      False
# 2023-05-21             84      False
# 2023-05-28             76      False
# 2023-06-04             83      False
# 2023-06-11             74      False
# 2023-06-18             64      False
# 2023-06-25            100      False
# 2023-07-02             69      False
# 2023-07-09             68      False
# 2023-07-16             64      False
# 2023-07-23             69      False
# 2023-07-30             86      False
# 2023-08-06             77      False
# 2023-08-13             80      False
# 2023-08-20             56      False
# 2023-08-27             85      False
# 2023-09-03             63      False
# ...

# %%
# PARA BUSCAR LOS TOPICS ID
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US', tz=360)
suggs = pytrends.suggestions("Labour Market")
suggs
# Out:
# [{'mid': '/m/011x5vx5',
#   'title': 'Labour Market Regulatory Authority',
#   'type': 'Governing body'},
#  {'mid': '/g/11j775y04_',
#   'title': 'Labour Market Impact Assessment',
#   'type': 'Topic'},
#  {'mid': '/g/121v2c3t', 'title': 'labour market subsidy', 'type': 'Topic'},
#  {'mid': '/g/12bpb3230',
#   'title': 'International Human Resource Management',
#   'type': 'Book'},
#  {'mid': '/g/1n36gmq6p',
#   'title': 'labour market contribution (Denmark)',
#   'type': 'Topic'}]

# %%
pytrend = TrendReq()
topics_data = pytrend.suggestions(keyword='Labour Market') # PARA METERNOS EN LABOUR MARKET
topics_data # SIGUEN SALIENDOME OTROS
# Out:
# [{'mid': '/m/011x5vx5',
#   'title': 'Labour Market Regulatory Authority',
#   'type': 'Governing body'},
#  {'mid': '/g/11j775y04_',
#   'title': 'Labour Market Impact Assessment',
#   'type': 'Topic'},
#  {'mid': '/g/121v2c3t', 'title': 'labour market subsidy', 'type': 'Topic'},
#  {'mid': '/g/12bpb3230',
#   'title': 'International Human Resource Management',
#   'type': 'Book'},
#  {'mid': '/g/1n36gmq6p',
#   'title': 'labour market contribution (Denmark)',
#   'type': 'Topic'}]

# %%
# Probamos con otra categoria
pytrends = TrendReq(hl='en-US', tz=360)
suggs = pytrends.suggestions("Credit, Loans & Personal Finance")
suggs
# NO ME SALEN LOS MISMOS QUE NOS DIERON, PORQUE SUGGESTION TE RECOMIENDA TOPICS PERO NO SON TODOS LOS TOPICS
# Out:
# [{'mid': '/g/12bm4cc9t',
#   'title': "On My Own Two Feet: A Modern Girl's Guide to Personal Finance",
#   'type': 'Book by Manisha Thakor and Sharon Kedar'},
#  {'mid': '/g/11gh2w4wc1',
#   'title': 'Personal Finance in Your 20s and 30s For Dummies',
#   'type': 'Book by Eric Tyson'},
#  {'mid': '/g/11cmck_43n',
#   'title': 'Discount Finance & Personal Credit Loans Mission',
#   'type': 'Topic'},
#  {'mid': '/g/11f3hdstcp',
#   'title': 'Suze Orman: For the Young, Fabulous & Broke',
#   'type': 'Topic'},
#  {'mid': '/g/11lcc9mdt7',
#   'title': 'Personal Finance for Teens and Young Adults: Financial Literacy Skills To Empower Your Future, Crush Your Debt & Build Smart Money Habits That Instill Lifelong Confidence',
#   'type': 'Topic'}]

# %%
# PROBAREMOS CON LOS TOPICS DIRECTAMENTE, primera prueba, "Unemployment benefits", DENTRO DE LABOUR MARKET
from pytrends.request import TrendReq
pytrend = TrendReq()

topics_data = pytrend.suggestions(keyword='Unemployment benefits')
topics_data # Y ASI PODEMOS ACCEDER A LOS TOPICS EN INDIVIDUAL, COMENTARLO CON RANDBEE
# NO PODEMOS ACCEDER A LOS TOPICS CON LAS CATEGORIAS INICIALES (EJEMPLO, INCLUYENDO LABOUR MARKET NO NOS SALEN LOS QUE RANDBEE NOS FACILITARON,
# PERO PODEMOS BUSCARLOS DIRECTAMENTE POR SUS NOMBRES)
# Out:
# [{'mid': '/m/0218w7', 'title': 'Unemployment benefits', 'type': 'Topic'},
#  {'mid': '/g/11j5_zdslp',
#   'title': 'Unemployment benefits in New Jersey',
#   'type': 'Topic'},
#  {'mid': '/g/11jg4j171x',
#   'title': 'Unemployment benefits in Ohio',
#   'type': 'Topic'},
#  {'mid': '/g/11jg4s451x',
#   'title': 'Unemployment benefits in New York',
#   'type': 'Topic'},
#  {'mid': '/g/11jg4ldpyf',
#   'title': 'Unemployment benefits in Texas',
#   'type': 'Topic'}]

# %%
# nueva prueba, metiendo argumentos nuevos en el objeto pytrends (timeout, retries...)
from pytrends.request import TrendReq

# Inicializar objeto pytrends
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360, timeout= (10,25), retries=2, backoff_factor=0.1, requests_args={'verify':False})

# Buscar topics relacionados con una palabra clave
topics = pytrends.suggestions('Jobs')

# Imprimir los topics encontrados
print("Topics relacionados con 'jobs':")
for topic in topics:
    print(topic)

# Seleccionar el código del topic de interés
topic_code = topics[0]['mid']  # Seleccionamos el primer topic como ejemplo

# Realizar la consulta a Google Trends utilizando el código del topic
pytrends.build_payload(kw_list=[topic_code], timeframe='today 12-m', geo='US')
data = pytrends.interest_over_time()

# Imprimir los datos obtenidos
print("\nDatos de Google Trends para el topic seleccionado:")
print(data)
# tampoco funciona, sale un error con un metodo que no hemos usado
# Out:
# c:\Users\Picar\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       7 pytrends = TrendReq(hl='en-US', tz=360, timeout= (10,25), retries=2, backoff_factor=0.1, requests_args={'verify':False})
#       9 # Buscar topics relacionados con una palabra clave
# ---> 10 topics = pytrends.suggestions('Jobs')
#      12 # Imprimir los topics encontrados
#      13 print("Topics relacionados con 'jobs':")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pytrends\request.py:577, in TrendReq.suggestions(self, keyword)
# ...

# %%
# PRUEBAS CON EL CODIGO EXTRAIDO DEL PROYECTO DE VALENCIA DE RICK
import pandas as pd
from pytrends.request import TrendReq
import time

# Descargar datos de Google Trends
def download_gtrends(termes, region):
    pytrends = TrendReq(hl='es-US', tz=360)
    all_gtseries = {}
    for i in termes:
        print(i)
        pytrends.build_payload([i], geo=region, timeframe='2007-01-01 ' + pd.Timestamp.now().strftime('%Y-%m-%d'))
        out_gtrends = pytrends.interest_over_time()
        all_gtseries[i] = out_gtrends[i].values
        time.sleep(10) 
    return all_gtseries

regions = ["ES"]
termes = ["jobs"]  # Puedes cambiar las palabras clave aquí

all_gtseries = {}
for region in regions:
    all_gtseries[region] = download_gtrends(termes, region)

# Guardar los datos descargados
for region, gtseries in all_gtseries.items():
    df = pd.DataFrame(gtseries, columns=termes)
    df.to_csv(f"data/gtseries/allgtseries_{region}.csv", index=False)

# Manipular las series temporales
# Suponiendo que p.fecha.ini está definido
start_date = '2007-01-01'  # Definir la fecha de inicio deseada

for region, gtseries in all_gtseries.items():
    for term, values in gtseries.items():
        ts_gtseries = pd.Series(values, index=pd.date_range(start=start_date, periods=len(values), freq='M'))
        # Realizar cualquier manipulación adicional que necesites con ts_gtseries
        print(ts_gtseries)
        
# MISMO ERROR
# Out:
# jobs
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# Cell In[24], line 23
#      21 all_gtseries = {}
#      22 for region in regions:
# ---> 23     all_gtseries[region] = download_gtrends(termes, region)
#      25 # Guardar los datos descargados
#      26 for region, gtseries in all_gtseries.items():
#
# Cell In[24], line 13, in download_gtrends(termes, region)
#      11 print(i)
#      12 pytrends.build_payload([i], geo=region, timeframe='2007-01-01 ' + pd.Timestamp.now().strftime('%Y-%m-%d'))
# ---> 13 out_gtrends = pytrends.interest_over_time()
#      14 all_gtseries[i] = out_gtrends[i].values
#      15 time.sleep(10)
#
# File c:\Users\Picar\AppData\Local\Programs\Python\Python39\lib\site-packages\pytrends\request.py:232, in TrendReq.interest_over_time(self)
#     224 over_time_payload = {
#     225     # convert to string as requests will mangle
# ...

# %%
# mas soluciones, BAJARNOS LA ULTIMA ULTIMISIMA VERSION DE PYTRENDS
# !pip install --upgrade --user git+https://github.com/GeneralMills/pytrends
from pytrends.request import TrendReq
import pandas as pd
# Out:
# ...
#   Cloning https://github.com/GeneralMills/pytrends to c:\users\picar\appdata\local\temp\pip-req-build-t_s4oek7
#   Resolved https://github.com/GeneralMills/pytrends to commit a9984ffdc9b31d853dde2ab614a77ecbf2bf33a1
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Running command git clone --filter=blob:none --quiet https://github.com/GeneralMills/pytrends 'C:\Users\Picar\AppData\Local\Temp\pip-req-build-t_s4oek7'
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# BUSCAMOS UNA FORMA DE MANEJAR ESTE ERROR, CON BATCH Y LA BIBLIOTECA TIME, PUES ES UN ERROR RELACIONADO CON HACER DEMASIADAS CONSULTAS EN POCO TIEMPO
import time
from pytrends.request import TrendReq

pytrends = TrendReq(timeout= (10,25))

keywords = ['Unemployment benefits']
batch_size = 3

for i in range(0, len(keywords), batch_size):
    batch = keywords[i:i+batch_size]
    pytrends.build_payload(kw_list=batch)
    time.sleep(5)  # Esperar 5 segundoS entre lotes

# %%
# y ahora, el interest
interest_over_time_df = pytrends.interest_over_time()
print(interest_over_time_df)
# nuevo error, ReadTimeout: HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=25)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File c:\Users\Picar\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\Picar\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File c:\Users\Picar\AppData\Local\Programs\Python\Python39\lib\http\client.py:1347, in HTTPConnection.getresponse(self)
#    1346 try:
# -> 1347     response.begin()
# ...

# %%
# PRUEBA DE JOSE, CON HEADERS, HEMOS HECHO EL PROCEDIMIENTO DE STACKOVERFLOW
from pytrends.request import TrendReq as UTrendReq
GET_METHOD='get'

import requests

headers = {{verbose ? " -v" : ""}}{{insecure ? " --insecure" : ""}}{{ method ? " -X" + method : ""}}{{ getHeadersString() }}{{json ? ' -H "Content-type: application/json"' : ""}}{{ data ? " -d '"+data+"'" : "" }} {{ endpoint ? "'"+endpoint+"'" : '' }}}


class TrendReq(UTrendReq):
    def _get_data(self, url, method=GET_METHOD, trim_chars=0, **kwargs):
        return super()._get_data(url, method=GET_METHOD, trim_chars=trim_chars, headers=headers, **kwargs)

# NO SE SI ES EL CODIGO QUE TENGO QUE METER, PERO ES EL QUE ME DABA LA PAGINA https://curlbuilder.com/, NO FUNCIONA
# Out:
#   Cell In[2], line 7
#     headers = {{verbose ? " -v" : ""}}{{insecure ? " --insecure" : ""}}{{ method ? " -X" + method : ""}}{{ getHeadersString() }}{{json ? ' -H "Content-type: application/json"' : ""}}{{ data ? " -d '"+data+"'" : "" }} {{ endpoint ? "'"+endpoint+"'" : '' }}}
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ESTO ES UN EJEMPLO EN CHATGPT, PERO SIGO SIN SABER QUE SON LOS HEADERS, NI SI LOS HE OBTENIDO BIEN CON LA PAGINA DE CURL
# LOS QUE OBTUVE DE LA PAGINA TRAS HACER LA PRUEBA EN GOOGLE TRENDS Y CON HERAMIENTAS DE PROGRAMADORES CREO QUE SON ESTOS
# curl{{verbose ? " -v" : ""}}{{insecure ? " --insecure" : ""}}{{ method ? " -X" + method : ""}}{{ getHeadersString() }}{{json ? ' -H "Content-type: application/json"' : ""}}{{ data ? " -d '"+data+"'" : "" }} {{ endpoint ? "'"+endpoint+"'" : '' }}
#
# from pytrends.request import TrendReq as UTrendReq
# import requests
#
# # Encabezados personalizados obtenidos del script de Python generado en curlbuilder.com
# headers = {
#     'User-Agent': 'TuAgenteDeUsuario',
#     'Referer': 'https://www.google.com/',
#     # Otros encabezados que puedan ser necesarios
# }
#
# # Subclase de TrendReq que incluye los encabezados personalizados
# class TrendReq(UTrendReq):
#     def _get_data(self, url, method='get', trim_chars=0, **kwargs):
#         return super()._get_data(url, method=method, trim_chars=trim_chars, headers=headers, **kwargs)
#
# # Ejemplo de uso
# pytrends = TrendReq()
# pytrends.build_payload(kw_list=['Python'], timeframe='today 5-y', geo='US')

# %%
# OTRA FORMA,
# INTENTANDO MANEJAR LOS ERRORES, con un try except (TENGO QUE METER EL FILTRO DE LOS PAISES Y LA SEMANA)
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe='2014-01-01 2024-03-31', geo='US')
        data = pytrends.interest_over_time()
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str):
    trends_data = obtener_datos_google_trends_semanal(topic)  # Usar 'topic' en lugar de 'palabra_clave'
    return trends_data.to_dict()

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                   25.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                   17.0        0.0
# ...                           ...        ...
# 2024-02-04                    5.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    5.0        1.0
#
# [531 rows x 2 columns]

# %%
# PERO LOS QUEREMOS SEMANALES, NO MENSUALES
def obtener_datos_google_trends_semanal(palabra_clave):
    try:
        # Intentar obtener datos de Google Trends
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe='2014-01-01 2024-03-31', geo='US')
        data = pytrends.interest_over_time(resolution='W')  # ESPECIFICAMOS SEMANAL, pero este parametro no existe!!!
        return data
    except Exception as e:
        # Si ocurre un error, imprimirlo y esperar antes de volver a intentar
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)  # Esperar 60 segundos 
        return obtener_datos_google_trends_semanal(palabra_clave)

# Ejemplo de uso
palabra_clave = "Jobs"
datos_semanales = obtener_datos_google_trends_semanal(palabra_clave)
datos_semanales
# Out:
# Error al obtener datos de Google Trends: interest_over_time() got an unexpected keyword argument 'resolution'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 7, in obtener_datos_google_trends_semanal(palabra_clave)
#       6 pytrends.build_payload(kw_list=[palabra_clave], timeframe='2014-01-01 2024-03-31', geo='US')
# ----> 7 data = pytrends.interest_over_time(resolution='W')  # ESPECIFICAMOS SEMANAL, pero este parametro no existe!!!
#       8 return data
#
# TypeError: interest_over_time() got an unexpected keyword argument 'resolution'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 17
#      15 # Ejemplo de uso
#      16 palabra_clave = "Jobs"
# ---> 17 datos_semanales = obtener_datos_google_trends_semanal(palabra_clave)
# ...

# %%
# NO FUNCIONA EL PARAMETRO RESOLUCION para cambiar a semanal, ASI QUE BUSCAMOS OTRA FORMA
import pandas as pd

def obtener_datos_google_trends_semanal(palabra_clave):
    try:
        # Intentar obtener datos de Google Trends
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe='2014-01-01 2024-03-31', geo='ES')
        data = pytrends.interest_over_time()
        
        # Convertir datos a frecuencia semanal
        data_semanal = data.resample('W').mean()
        
        return data_semanal
    except Exception as e:
        # Si ocurre un error, imprimirlo y esperar antes de volver a intentar
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)  # Esperar 60 segundos (ajustar según sea necesario)
        return obtener_datos_google_trends_semanal(palabra_clave)

# Ejemplo de uso
palabra_clave = "Jobs"
datos_semanales = obtener_datos_google_trends_semanal(palabra_clave)
datos_semanales
# NO SALE CORRECTAMENTE PORQUE TIENE LOS DATOS POR MESES, NO POR SEMANA. eL RESAMPLEO NO HA SERVIDO
# SI QUEREMOS PONER DE FILTRO QUE SEA DE 2004 HASTA AHORA, TODO EL HISTORICO, NOS SALE POR MES
# HABRIA QUE DECIDIR SI METER OTROS FILTROS DE TIEMPO (que si que nos de semanales, como los mensuales aunque es mas curro)
# Out:
#             Jobs  isPartial
# date
# 2014-01-05  60.0        0.0
# 2014-01-12   NaN        NaN
# 2014-01-19   NaN        NaN
# 2014-01-26   NaN        NaN
# 2014-02-02  51.0        0.0
# ...          ...        ...
# 2024-02-04  60.0        0.0
# 2024-02-11   NaN        NaN
# 2024-02-18   NaN        NaN
# 2024-02-25   NaN        NaN
# 2024-03-03  55.0        1.0
#
# [531 rows x 2 columns]
